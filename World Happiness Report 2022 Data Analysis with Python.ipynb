# %% [markdown]
# # **World Happiness Report 2022 Data Analysis with Python**
# ## **About Dataset**
# The first World Happiness Report was released on April 1, 2012 as a foundational text for the UN High Level Meeting: Well-being and Happiness: Defining a New Economic Paradigm, drawing international attention. The report outlined the state of world happiness, causes of happiness and misery, and policy implications highlighted by case studies. In 2013, the second World Happiness Report was issued, and since then has been issued on an annual basis with the exception of 2014. The report primarily uses data from the Gallup World Poll. Each annual report is available to the public to download on the World Happiness Report website.
#
# ## **Content**
# The happiness scores and rankings use data from the Gallup World Poll. The scores are based on answers to the main life evaluation question asked in the poll. This question, known as the Cantril ladder, asks respondents to think of a ladder with the best possible life for them being a 10 and the worst possible life being a 0 and to rate their own current lives on that scale. The scores are from nationally representative samples for the years 2013-2022 and use the Gallup weights to make the estimates representative. The columns following the happiness score estimate the extent to which each of six factors – economic production, social support, life expectancy, freedom, absence of corruption, and generosity.
#
# The following columns: GDP per Capita, Family, Life Expectancy, Freedom, Generosity, Government Corruption describe the extent to which these factors contribute in evaluating the happiness in each country.
#
# I’ll cover the following topics data analysis:
#
# 1. Loading the Dataset.
# 2. Understanding the Dataset.
# 3. Cleaning the Dataset.
# 4. Data Visualization.
# 5. Conclusion.
#
# *Let’s dive in!*

# %% [markdown]
# ### 1. Loading The Data
# Let's import the dataset. I’m going to load the dataset using Pandas. Let's me import Pandas first.

# %%
import pandas as pd

# %%
data2022 = pd.read_csv('2022.csv')

# %% [markdown]
# Now, let’s take a look at the first rows of the dataset. To do this I’m going to use the head method.

# %%
data2022.head()
# Out:
#    RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0     1      Finland            7.821         7.886        7.756
# 1     2      Denmark            7.636         7.710        7.563
# 2     3      Iceland            7.557         7.651        7.464
# 3     4  Switzerland            7.512         7.586        7.437
# 4     5  Netherlands            7.415         7.471        7.359
#
#    Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                       2.518                         1.892
# 1                       2.226                         1.953
# 2                       2.320                         1.936
# 3                       2.153                         2.026
# 4                       2.137                         1.945
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.258                                  0.775
# ...

# %% [markdown]
# ### 2. Understanding The Dataset
#
# Understanding the data is very important before any analysis. For example, let’s see the number of rows and columns of the dataset. I’m going to use the shape attribute to do this.

# %%
data2022.shape
# Out:
# (146, 12)

# %% [markdown]
# As we can see, the dataset has 146 rows and 12 columns. Now, I’m going to use the info method to get more information about the dataset.

# %%
data2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 12 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   RANK                                        146 non-null    int64
#  1   Country                                     146 non-null    object
#  2   Happiness score                             146 non-null    float64
#  3   Whisker-high                                146 non-null    float64
#  4   Whisker-low                                 146 non-null    float64
#  5   Dystopia (1.83) + residual                  146 non-null    float64
#  6   Explained by: GDP per capita                146 non-null    float64
#  7   Explained by: Social support                146 non-null    float64
#  8   Explained by: Healthy life expectancy       146 non-null    float64
# ...

# %% [markdown]
# There is absolutely no missing data in the dataset. We can also use the isnull method to see if there is a missing data.

# %%
data2022.isnull()
# Out:
#       RANK  Country  Happiness score  Whisker-high  Whisker-low  \
# 0    False    False            False         False        False
# 1    False    False            False         False        False
# 2    False    False            False         False        False
# 3    False    False            False         False        False
# 4    False    False            False         False        False
# ..     ...      ...              ...           ...          ...
# 141  False    False            False         False        False
# 142  False    False            False         False        False
# 143  False    False            False         False        False
# 144  False    False            False         False        False
# 145  False    False            False         False        False
#
#      Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                         False                         False
# 1                         False                         False
# ...

# %% [markdown]
# Now let use the sum method to see the sum of the missing data.

# %%
data2022.isnull().sum()
# Out:
# RANK                                          0
# Country                                       0
# Happiness score                               0
# Whisker-high                                  0
# Whisker-low                                   0
# Dystopia (1.83) + residual                    0
# Explained by: GDP per capita                  0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# dtype: int64

# %%
data2022.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 141    False
# 142    False
# 143    False
# 144    False
# 145    False
# Length: 146, dtype: bool

# %% [markdown]
# As we can see, there is no missing data and no duplicate in the dataset at all.
# Now, let’s go ahead and take a look at the statistics of numeric variables with the describe method.

# %%
data2022.describe()
# Out:
#              RANK  Happiness score  Whisker-high  Whisker-low  \
# count  146.000000       146.000000    146.000000   146.000000
# mean    73.500000         5.553575      5.673589     5.433568
# std     42.290661         1.086843      1.065621     1.109380
# min      1.000000         2.404000      2.469000     2.339000
# 25%     37.250000         4.888750      5.006250     4.754750
# 50%     73.500000         5.568500      5.680000     5.453000
# 75%    109.750000         6.305000      6.448750     6.190000
# max    146.000000         7.821000      7.886000     7.756000
#
#        Dystopia (1.83) + residual  Explained by: GDP per capita  \
# count                  146.000000                    146.000000
# mean                     1.831808                      1.410445
# std                      0.534994                      0.421663
# min                      0.187000                      0.000000
# 25%                      1.555250                      1.095500
# ...

# %% [markdown]
# ### 3. Cleaning the Dataset.
#
# Cleaning the data is very important before any further analysis. For example, renaming the columns for easier use.
# Let's rename the some columns in the dataset.

# %%
data2022.rename(columns = {'Explained by: Healthy life expectancy':'Healthy Life Expectancy',
                       'Explained by: Freedom to make life choices':'Freedom to make life choices',
                       'Explained by: Generosity':'Generosity',
                       'Explained by: Perceptions of corruption':'Government Corruption',
                        'Explained by: Social support':'Social Support',
                        'Explained by: GDP per capita':'GDP per capita',}, inplace = True)
data2022
# Out:
#      RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0       1      Finland            7.821         7.886        7.756
# 1       2      Denmark            7.636         7.710        7.563
# 2       3      Iceland            7.557         7.651        7.464
# 3       4  Switzerland            7.512         7.586        7.437
# 4       5  Netherlands            7.415         7.471        7.359
# ..    ...          ...              ...           ...          ...
# 141   142    Botswana*            3.471         3.667        3.275
# 142   143      Rwanda*            3.268         3.462        3.074
# 143   144     Zimbabwe            2.995         3.110        2.880
# 144   145      Lebanon            2.955         3.049        2.862
# 145   146  Afghanistan            2.404         2.469        2.339
#
#      Dystopia (1.83) + residual  GDP per capita  Social Support  \
# 0                         2.518           1.892           1.258
# ...

# %% [markdown]
# Much better, now let's drop some columns that we won't need.

# %%
data2022 = data2022.drop(columns=['Whisker-high', 'Whisker-low', 'Dystopia (1.83) + residual'])
data2022
# Out:
#      RANK      Country  Happiness score  GDP per capita  Social Support  \
# 0       1      Finland            7.821           1.892           1.258
# 1       2      Denmark            7.636           1.953           1.243
# 2       3      Iceland            7.557           1.936           1.320
# 3       4  Switzerland            7.512           2.026           1.226
# 4       5  Netherlands            7.415           1.945           1.206
# ..    ...          ...              ...             ...             ...
# 141   142    Botswana*            3.471           1.503           0.815
# 142   143      Rwanda*            3.268           0.785           0.133
# 143   144     Zimbabwe            2.995           0.947           0.690
# 144   145      Lebanon            2.955           1.392           0.498
# 145   146  Afghanistan            2.404           0.758           0.000
#
#      Healthy Life Expectancy  Freedom to make life choices  Generosity  \
# ...

# %% [markdown]
# I will save this cleaned dataset for Tableau visualization also.

# %%
data2022.to_csv('2022update.csv')

# %% [markdown]
# Done.

# %% [markdown]
# Now let's see correlation map.

# %%
data2022.corr()
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_10352\2858354024.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data2022.corr()
#                                   RANK  Happiness score  GDP per capita  \
# RANK                          1.000000        -0.980856       -0.792137
# Happiness score              -0.980856         1.000000        0.763677
# GDP per capita               -0.792137         0.763677        1.000000
# Social Support               -0.773773         0.777889        0.722421
# Healthy Life Expectancy      -0.750945         0.740260        0.815386
# Freedom to make life choices -0.623040         0.624822        0.458591
# Generosity                   -0.032831         0.063785       -0.164472
# Government Corruption        -0.403199         0.416216        0.377589
#
# ...

# %% [markdown]
# ### 4. Data Visualization
# We can understand the dataset much much better with visualization. Now, let look at the relationships of numeric variables using the seaborn. First, let's import the tools we will need.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# In order to check the distribution of values within a column, we can employ various plots, and one of the best ways to easily display the distribution of values is a histogram.

# %%
sns.displot(data=data2022, x="Happiness score", label='2022', kde = True, color="blue")
plt.title('Histogram of Happiness', fontsize=17)
# Out:
# Text(0.5, 1.0, 'Histogram of Happiness')

# %% [markdown]
# **Relationships between Variables**
#
# Now that we have a good idea about the structure of the dataset, we can dive into relationships between variables. One of the ways to quickly check the correlations between variables is by running df.corr() which we did ealier, which returned a table of all correlations. However, to get a more clear view of correlations, we turn to data visualization and one of the best method is a heatmap.

# %%
sns.heatmap(data2022.corr(), annot= True)
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_10352\2436581417.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data2022.corr(), annot= True)
# <AxesSubplot: >

# %% [markdown]
# The heatmap produces darker colors for stronger correlations, and the annotations show the correlation coefficient. For example, ‘Healthy Life Expectancy’ and ‘GDP per capita’ have a 0.82 correlation, which means these two variables are strongly correlated.

# %% [markdown]
# Another great way to take a look at the relationship between two variables is a scatter plot. Note, here we are only looking at two variables at a time. A scatter plot is a very useful tool on its own, but they also complement the correlation matrix very well, helping you draw more insights from the data.

# %%
plt.scatter(data = data2022, x = "GDP per capita", y = "Happiness score")
plt.xlabel('GDP per capita')
plt.ylabel('Happiness Score')
plt.title('GDP vs. Happiness', fontsize=17)
# Out:
# Text(0.5, 1.0, 'GDP vs. Happiness')

# %% [markdown]
# We can see a strong correlation between Gross Domestic Product (GDP) and Happiness.

# %%
plt.scatter(data = data2022, x = "Healthy Life Expectancy", y = "GDP per capita")
plt.xlabel('Healthy Life Expectancy')
plt.ylabel('GDP per capita')
plt.title('GDP per capita vs. Healthy Life Expectancy', fontsize=15)
# Out:
# Text(0.5, 1.0, 'GDP per capita vs. Healthy Life Expectancy')

# %% [markdown]
# Also, a strong correlation between GDP and Healthy Life Expectancy, wealthier countries live a longer healthier life.

# %%
plt.scatter(data = data2022, x = "Healthy Life Expectancy", y = "Happiness score")
plt.xlabel('Healthy Life Expectancy')
plt.ylabel('Happiness Score')
plt.title('Healthy Life Expectancy vs. Happiness', fontsize=17)
# Out:
# Text(0.5, 1.0, 'Healthy Life Expectancy vs. Happiness')

# %% [markdown]
# Positive correlation between Healthy Life Expectancy and Happiness.

# %%
plt.scatter(data = data2022, x = "Freedom to make life choices", y = "Happiness score")
plt.xlabel('Freedom')
plt.ylabel('Happiness Score')
plt.title('Freedom vs. Happiness', fontsize=17)
# Out:
# Text(0.5, 1.0, 'Freedom vs. Happiness')

# %% [markdown]
# Countries with more freedom to make life choices also positively correlates to happiness.

# %%
plt.scatter(data = data2022, x = "Social Support", y = "Happiness score")
plt.xlabel('Social Support')
plt.ylabel('Happiness Score')
plt.title('Social Support vs. Happiness', fontsize=17)
# Out:
# Text(0.5, 1.0, 'Social Support vs. Happiness')

# %% [markdown]
# As well as Social Support.

# %% [markdown]
# Let's see the relationship between all variables by using pairplot.

# %%
sns.pairplot(data2022)

# %% [markdown]
# Let's see the top10 best countries by visualizing the dataset with the max value of GDP per capita, Social Support, Healthy Life Expectancy and Freedom to make life choices.

# %%
fig, axes = plt.subplots(nrows=2, ncols=2,constrained_layout=True,figsize=(12,8))

sns.barplot(x='GDP per capita',y='Country',data=data2022.nlargest(10,'GDP per capita'),ax=axes[0,0],palette="Blues_d")

sns.barplot(x='Social Support' ,y='Country',data=data2022.nlargest(10,'Social Support'),ax=axes[0,1],palette="YlGn")

sns.barplot(x='Healthy Life Expectancy' ,y='Country',data=data2022.nlargest(10,'Healthy Life Expectancy'),ax=axes[1,0],palette='OrRd')

sns.barplot(x='Freedom to make life choices' ,y='Country',data=data2022.nlargest(10,'Freedom to make life choices'),ax=axes[1,1],palette='YlOrBr')
# Out:
# <AxesSubplot: xlabel='Government Corruption', ylabel='Country'>

# %%
fig, axes = plt.subplots(nrows=1, ncols=1,constrained_layout=True,figsize=(7,4))

sns.barplot(x='Government Corruption',y='Country',data=data2022.nlargest(10,'Government Corruption'),palette="Blues_d")
# Out:
# <AxesSubplot: xlabel='Government Corruption', ylabel='Country'>

# %% [markdown]
# The least corrupted country on earth is singapore.

# %%
fig, axes = plt.subplots(nrows=2, ncols=2,constrained_layout=True,figsize=(12,8))

sns.barplot(x='GDP per capita',y='Country',data=data2022.nsmallest(10,'GDP per capita'),ax=axes[0,0],palette="Blues_d")

sns.barplot(x='Social Support' ,y='Country',data=data2022.nsmallest(10,'Social Support'),ax=axes[0,1],palette="YlGn")

sns.barplot(x='Healthy Life Expectancy' ,y='Country',data=data2022.nsmallest(10,'Healthy Life Expectancy'),ax=axes[1,0],palette='OrRd')

sns.barplot(x='Freedom to make life choices' ,y='Country',data=data2022.nsmallest(10,'Freedom to make life choices'),ax=axes[1,1],palette='YlOrBr')
# Out:
# <AxesSubplot: xlabel='Freedom to make life choices', ylabel='Country'>

# %%
fig, axes = plt.subplots(nrows=1, ncols=1,constrained_layout=True,figsize=(7,4))

sns.barplot(x='Government Corruption' ,y='Country',data=data2022.nsmallest(10,'Government Corruption'), palette='YlOrBr')
# Out:
# <AxesSubplot: xlabel='Government Corruption', ylabel='Country'>

# %% [markdown]
# Corruption from bad to worst, the worst being croatia.

# %% [markdown]
# *Note: Those with a * do not have survey information in 2022. Their averages are based on the 2019 survey.*

# %% [markdown]
# ### Results
# We can see the following results from this visualization as follows:
# - The country with the highest GPD per capita is Luxembourg.
# - Highest with Social Support is Iceland.
# - Highest with Healthy Life Expectancy is Hong Kong S.A.R of China.
# - And with highest with Freedom to make life choices as Cambodia.
# - Least corrupted country being Singapore and worst being Croatia. *(Although further data is needed)*

# %% [markdown]
# ### 5. Conclusion
# - Wealthier countries and ones that have sustained economic growth tend to have higher average happiness levels.
# - Healthier countries also tend to have a happier population.
# - However, healthier countries also tend to be wealthy.
# - Evidence suggests that wealth, health, and happiness go together.
# - ###### Does not mean there is a casual effect. Further analysis needed.

# %% [markdown]
# #### In 2022 World Happiness Report Data Analysis We graphed happiness score with GDP per capita, Health, Life Expenctancy and Freedom. From this, we can see a positive correlation. As the above variables increase so does the overal happiness score. This is very informative and gives us insight into why people are happy in certain countries. ####
